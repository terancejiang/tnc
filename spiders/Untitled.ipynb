# %%
from urllib import urlencode
import urllib2

import requests

# %%
payload = {
    'appUserLoginId':'12000970',
    'password':'hengyi123'
}
with requests.Session() as s:
    p = s.post('http://hengyi.study.163.com/', data=payload)
    # print the html returned or something more intelligent to see if it's a successful login page.
#     print p.text

    # An authorised request.
    r = s.get('http://hengyi.study.163.com/resource/courses')
    print r.text
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <script>location.config = {root:'/pub/h/com/web/',mode:0,ver:{"course/course.html":"171b2eb4121141d424b23c63a5ebcc9f","course/micro.html":"6dfe53ebdc9704fb236f22f89db994e3","index/root.html":"ef2e19c750023ec5bf8fb620fe8a41bd","member/setting/account.html":"6751ab533f28734d4c350483aef85756","member/setting/info.html":"33ce21f542caed710fe6712aefb890c3","member/setting/msg.html":"4ae57cc05b1536451eece06d4464ef51","member/setting/root.html":"5059b52462d1421c20fd87c397df4231","module-cert/src/component/cert-member-import/component.html":"f07b3b0a98f949d8e56a5dd4646d1002","module-cert/src/component/cert-render/component.html":"8aded8ed6bdad426b8489bb2310f2a96","module-cert/src/component/my-cert-card/component.html":"b9efb59b650f68e0c81815f06a93f676","module-cert/src/component/my-cert-list/component.html":"80bb333062d8727b80dec832219e7c91","module-cert/src/component/ux-cert-drag/component.html":"9da99454b855d6ff23b4bf018daceaff","module-cert/src/component/ux-cert-upload/component.html":"9a8d5c892f5306192ad7bd54c076c93b","module-cert/src/edit/baseinfo/index.html":"eb5b05f646e5c7b2c58524b32af65ade","module-cert/src/edit/component/baseinfo/component.html":"722b164d313325a2061210a6d012d0fc","module-cert/src/edit/component/editHead/component.html":"a98c7c0916202e4fb06fc2b79846b883","module-cert/src/edit/component/make/component.html":"dcd1dac656417b9fb3d3375f24e21152","module-cert/src/edit/layout/index.html":"1298436df050894c066c87da5780ecf1","module-cert/src/edit/make/index.html":"f51612ca85185493a3c4a24fb45d8eca","module-cert/src/import/index.html":"226b85503ed20de2e57070330cd3df61","module-cert/src/list/component/addModal/component.html":"7352b88ec9656c61467ba900ec6cbe98","module-cert/src/list/component/list/component.html":"7514c3cba2a1e307216f9b787f78528d","module-cert/src/list/component/list/templete.html":"cfa28b1528239f925c3a20a076db5c7f","module-cert/src/list/component/listItem/component.html":"477368316e0bba5b17a6fa34e3261cdc","module-cert/src/list/index.html":"7ea27b1afca2df9dd949097b382e8e5d","module-cert/src/myCert/index.html":"c8f01dcecb4fc804ea368368b3558776","module-cert/src/send/confirm/component/ux-confirm/component.html":"0ed7e5da3dcabfafd6a28e50a4afe729","module-cert/src/send/confirm/index.html":"9b74e3a241561f0056ae14503524257c","module-cert/src/send/layout/index.html":"b98e45d1a859612029b34d77b977437f","module-cert/src/send/list/component/ux-send-list/component.html":"fb07f7bcf92dc281715d1838baed19ca","module-cert/src/send/list/index.html":"01a11ffc939dfeb3a08261c52c499e1c","module-cert/src/send/result/component/ux-result-list/component.html":"16c60ff4be6d4fcb0ad2e52b8711ecf6","module-cert/src/send/result/index.html":"579de0497da835fbe911b05472e81acc","module-classification/src/classify/index.html":"c57577d6c07c49ec4365fc7d51e9a325","module-classification/src/component/ux-classify/component.html":"9123ee4f4de209a91a667619ba02a8cb","module-classification/src/component/ux-management/component.html":"4165e85d44dc9083f70cd4f76b93fc83","module-classification/src/component/ux-old-management/component.html":"7ccb4a3f6e767cf70d487f96ed1f02b8","module-classification/src/layout/index.html":"87a4534805b05c82cb2dcbe3a3b58ea1","module-classification/src/management/index.html":"5eff384b869789d09196ffc914edc061","module-column/src/admin/index.html":"c12a113f5db4564da7a1472670bf3f5c","module-column/src/admin/list/component/src/ux-admin-column-item/component.html":"a507f535d70c8378e2ad798986a7a553","module-column/src/admin/list/component/src/ux-admin-column-list/component.html":"7a4ab0a54cf03d5be35cc27f2c3c20dc","module-column/src/admin/list/index.html":"5d2995a0bbe6b719e802c2af522ec898","module-column/src/admin/preview/component/src/ux-admin-article-preview/component.html":"a72a73db18eeefb2e9aa99a6696bdd7a","module-column/src/admin/preview/index.html":"26e21984f3eea495d6aa4c7cd420064d","module-column/src/admin/unverify/column/index.html":"8808f8b4cb0b4b365232ac04c5415937","module-column/src/admin/unverify/component/src/ux-unverify-c ...
# <script>
# (function(g){
# g.eduProduct = {
# "siteName": "网易云课堂企业版",
# "siteLogo": "http://se.stu.126.net/res/images/common/logo/logo2.png",
# "host": "study.163.com",
# "initUploadUrl": "/enterprise/UploaderCenterManager/getEduUploaderToken.do",
# "logoutUrl": "/passport/member/logout.htm",
# "gaAccount": "UA-35176345-6",
# "gaProduct": "qyy"
# }
# })(window);
# </script><script>
# window.isCom = true; // 企业页面识别
# </script><meta charset="utf-8"/>
# <title>恒逸网络学堂</title>
# <meta name="description" content="恒逸网络学堂,云课堂,"/>
# <meta name="keywords" content="恒逸网络学堂,云课堂,"/>
# <script>
# var qyyErrorLog = (function (){
# /*引自nej util/encode/md5 */
# var __chrsz = 8;
# var __str2bin = (function(){
# var _lmove = function(i){return i%32;},
# _bmove = function(i){return 32-__chrsz-i%32;};
# return function(_str,_little){
# var _bin = [],
# _mask = (1<<__chrsz)-1,
# _move = _little?_lmove:_bmove;
# for (var i=0,l=_str.length*__chrsz;i<l;i+=__chrsz)
# _bin[i>>5] |= (_str.charCodeAt(i/__chrsz)&_mask)<<_move(i);
# return _bin;
# };
# })();
# var __bin2hex = (function(){
# // hex output table.
# var _hextab = '0123456789abcdef',
# _lmove = function(i){return i%4;},
# _bmove = function(i){return 3-i%4;};
# return function(_binarray,_little){
# var _arr = [],
# _move = _little?_lmove:_bmove;
# for(var i=0,l=_binarray.length*4;i<l;i++){
# _arr.push(_hextab.charAt((_binarray[i>>2]>>(_move(i)*8+4))&0xF)
# +_hextab.charAt((_binarray[i>>2]>>(_move(i)*8))&0xF));
# }
# return _arr.join('');
# };
# })();
# /*end */
# var logError = {
# searchFtlError : function(){
# if(!eval) return;
# var docts = document.getElementsByTagName('html')[0].innerHTML;
# var re = eval("/FreeMarker template error/g");
# if(docts.match(re).length > 1){
# var errorInfo = {
# type : 'freemarker',
# ua : navigator.userAgent,
# url : location.href
# };
# logError.sendLog(errorInfo);
# }
# },
# listenError : function (){
# var olderror = console.error;
# console.error = function(arguments){
# olderror(arguments);
# logError.logError(arguments);
# }
# window.onload = function(){
# logError.searchFtlError();
# }
# window.onerror = this.logError;
# window.addEventListener ? window.addEventListener('error',this.logError) : window.attachEvent('error',this.logError);
# document.addEventListener ? document.addEventListener('error',this.logError,true) : document.attachEvent('error',this.logError);
# },
# logError : function (){
# var error, _error, errorTarget, errorInfo,
# ua = navigator.userAgent;
# if(arguments.length > 1){ //winodw.onerror监听数据
# error = arguments[0];
# errorInfo = {
# msg : error,
# type : 'runtime',
# ua : ua,
# url : location.href,
# stack : arguments[4] && arguments[4].stack
# };
# logError.sendLog(errorInfo);
# }else{
# errorTarget = arguments[0].target ? arguments[0].target : arguments[0].srcElement;
# error = arguments[0];
# if(errorTarget && errorTarget !== window ){ //file unload监听数据
# errorInfo = {
# file : errorTarget.src || errorTarget.href,
# type : 'loaderror',
# ua : ua ,
# url : location.href
# }
# logError.sendLog(errorInfo);
# }else if(error.message){ //console.onerror 监听数据
# _error = error.message,
# errorInfo = {
# msg : _error,
# type : 'consoleerror',
# ua : ua,
# url : location.href
# };
# logError.sendLog(errorInfo);
# }
# }
# },
# checkErrorsStorage : function(url, _errorInfo){//同一页面报错刷新不发送多次请求
# if(!sessionStorage) return true;
# var key = "qyy_" + url;
# if(sessionStorage.getItem(key)){
# return false
# }else{
# sessionStorage.setItem(key, _errorInfo);
# return true;
# }
# return true
# },
# sendLog : function(errorInfo){
# errorInfo.action = 'pageerror';
# console.log(errorInfo);
# if(!JSON || !JSON.stringify) return;
# var _errorInfo = JSON.stringify(errorInfo);
# if(!logError.checkErrorsStorage(errorInfo.url, _errorInfo)) return;
# logError.pushLog(logError.str2hex(_errorInfo));
# },
# str2hex : function(obj){
# return __bin2hex(__str2bin(obj, true), true);
# },
# pushLog : function(paramsStr){
# var _e = document.createElement('img');
# _e.src = '//log.study.163.com/__utm.gif?p=qyy&dt=' + paramsStr;
# }
# }
# return logError;
# })()
# qyyErrorLog.listenError()
# </script>
# <link rel = "Shortcut Icon" href="http://edu-image.nosdn.127.net/f44d367d-28d1-409d-8b37-7d4d585037f9.png?imageView&amp;quality=100">
# <meta http-equiv="content-type" content="text/html;charset=utf-8"/>
# <meta http-equiv="x-dns-prefetch-control" content="on"/>
# <link rel="dns-prefetch" href="//s.stu.126.net"/>
# <link rel="dns-prefetch" href="//study.163.com"/>
# <link rel="dns-prefetch" href="//sb.stu.126.net"/>
# <link rel="dns-prefetch" href="//b.study.163.com"/>
# <link rel="dns-prefetch" href="//mc.stu.126.net"/>
# <link rel="dns-prefetch" href="//mooc.study.163.com"/>
# <link rel="dns-prefetch" href="//imgsize.ph.126.net"/>
# <link rel="dns-prefetch" href="//img0.ph.126.net"/>
# <link rel="dns-prefetch" href="//img1.ph.126.net"/>
# <link rel="dns-prefetch" href="//img2.ph.126.net"/>
# <link rel="dns-prefetch" href="//edu-image.nosdn.127.net"/>
# <meta http-equiv="Pragma" content="no-cache"/>
# <meta http-equiv="Cache-Control" content="no-cache" max-age="0"/>
# <meta http-equiv="Expires" content="0"/>
# <meta name="author" content="Netease"/>
# <meta name="version" content="1.0"/>
# <meta name="robots" content="all"/>
# <meta property="wb:webmaster" content="766092f2bbf0c80d" />
# <meta property="qc:admins" content="22061604124161636375" />
# <meta name="baidu-site-verification" content="BYFmFBILbh" />
# <meta name="sogou_site_verification" content="OYmk13vRd8"/>
# <meta name="360-site-verification" content="3f6a1f60c79c924896ff3ad0361a7ae4" />
# <meta name="shenma-site-verification" content="3c734e0249d2a18b010e2f91efebe76e_1456214629"/>
# <meta name="google-site-verification" content="z_KJAVxXT-GQ_nSWb0Vgt3ixceS3si1I8baDikd64uM" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <meta name="renderer" content="webkit"><link rel="stylesheet" href="http://se.stu.126.net/pub/s/com/web/pt_com_web_member_login_07cc8f749f68f1109c443b6748660bf4.css"/>
# </head>
# <body>
# <script>
# window.siteInfo = {"iconUrl": "http://edu-image.nosdn.127.net/f44d367d-28d1-409d-8b37-7d4d585037f9.png?imageView&quality=100","startTime": 1505865600000,"loginBgUrl": "http://edu-image.nosdn.127.net/d0c60efa-febb-4364-9bf8-90b5b3f3e274.jpg?imageView&quality=100","accountCharSupport": 0,"loginWay": 1,"siteProperty": "上市公司","siteId": 400000000162001,"providerName": "浙江恒逸集团有限公司","bonusCourseQuota": 500,"mobLoginBgUrl": "http://edu-image.nosdn.127.net/e1459fd9-9b5c-4741-908f-8ab79d25459e.jpg?imageView&quality=100","expTime": 1537660800000,"maxUserNum": 1001,"watermarkStatus": 0,"siteSize": 5,"maxCourseNum": 9999,"status": 1,"logoUrl": "http://edu-image.nosdn.127.net/f44d367d-28d1-409d-8b37-7d4d585037f9.png?imageView&quality=100","loginWaySets": "[0]","id": 400000000162001,"userNumLimitType": 0,"logoNavUrl": "http://edu-image.nosdn.127.net/f44d367d-28d1-409d-8b37-7d4d585037f9.png?imageView&quality=100","siteName": "恒逸网络学堂","maxConcurrencyUserNum": 999999,"siteDomain": "hengyi","siteCategory": "贸易/消费/制造/营运","providerId": 400000000233006};
# window.siteLoginWay = 1;
# window.serverTimeDiff = 0;
# window.im_site_prefix = "\//chat.study.163.com/study-chat";
# window.mobileInfo = {"downloadUrlAndroid": "http://study.163.com/pub/enterprise/pkg/study_enterprise_1_8_9_2018041116.apk","downloadUrlIphone": "https://itunes.apple.com/cn/app/id1136535619"};
# window.gaTrackPageview = '_trackPageview';
# window.gaTrackEvent = '_trackEvent';
# window.gaqStr = '_gaq';
# var _ua = 'UA-35176345-6';
# window._gaq = [];
# window._gaq.push(['_setAccount', _ua],['_setLocalGifPath', '/'+_ua+'/__utm.gif'],['_setLocalRemoteServerMode']);
# window._gaq.push(['_addOrganic', 'm.baidu.com', 'word']);
# window._gaq.push(['_addOrganic', 'soso', 'search']);
# window._gaq.push(['_addOrganic', 'sogou', 'query']);
# window._gaq.push(['_addOrganic', 'haosou', 'q']);
# window._gaq.push(['_addOrganic', 'youdao', 'q']);
# window._gaq.push(['_addOrganic', 'chinaso', 'q']);
# window._gaq.push(['_addOrganic', 'zhongsou', 'w']);
# window._gaq.push(['_addOrganic', 'm.sp.sm.cn', 'w']);
# (function() {
# var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# ga.src = 'http://wr.da.netease.com/ga.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# })();
# ﻿
# window.defaultConfig = {
# avatar:'http://se.stu.126.net/res/images/common/default/userface_8fd80077a3f6f8724937a32688e21cfc.png',
# coursecover: "http://se.stu.126.net/res/images/common/default/defaultcourse_b203c8c3b613f996ee3df890d4657bce.png",
# logomascot: "http://se.stu.126.net/res/images/common/logo/logo_mascot_b6e90fc0ed857b6f3210f16136a19bf3.png"
# };
# window.NEJ_CONF ={
# clipboard:'http://se.stu.126.net/res/swf/nej_clipboard_0eba83544b107d7207d8936baab41283.swf'
# };
# </script><div class="m-simple-nav">
# <div class="middle f-cb">
# <div class="com-logo f-fl">
# <img src="http://edu-image.nosdn.127.net/f44d367d-28d1-409d-8b37-7d4d585037f9.png?imageView&amp;quality=100&amp;thumbnail=0x50" height="50px" alt="企业logo">
# </div>
# <span id="j-download" class="f-fr download">
# <a class="itm">下载APP</a>
# <div id="j-download-layer" class="download-layer" style="display:none">
# <div class="pic">
# <img src="http://se.stu.126.net/res/images/com/common/nav/appDownload_qrcode_0ec6fcaaed04c428d6fbb015ec32680f.png" alt="App下载" width="140" height="140">
# </div>
# <div class="links">
# <p>扫码下载官方App</p>
# <a class="android" href="http://study.163.com/pub/enterprise/pkg/study_enterprise_1_8_9_2018041116.apk" target="_blank">云课堂企业云Android App下载</a>
# <a class="iOS" href="https://itunes.apple.com/cn/app/id1136535619" target="_blank">云课堂企业云iOS App下载</a>
# </div>
# </div>
# </span>
# </div>
# </div><div class="g-content" style="background-image:url(http://edu-image.nosdn.127.net/d0c60efa-febb-4364-9bf8-90b5b3f3e274.jpg?imageView&quality=100);" >
# <div class="m-login-box" id="j-login">
# </div>
# </div>
# <div class="m-yktFoot g-footer" id="j-yktfoot">
# <div class="g-flow ftwrapper f-cb">
# <span class="sep f-fs12"><a href="http://study.163.com" target="_blank">网易云课堂</a>&nbsp;提供技术支持</span><span class="f-fcf">|</span>
# <span class="sep f-fs12"><a id="j-org-protocol" target="_blank" class="link">服务协议</a></span>
# </div>
# </div><script type="text/javascript" src="https://webzj.reg.163.com/webapp/javascript/page/json3.js"></script>
# <script>
# </script>
# <script src="http://se.stu.126.net/pub/s/com/web/t_common_macro-common_m0_be0c46724328e5827381cc02a99e3489.js"></script>
# <script src="https://qiyukf.com/script/709c368e01898339191608cad8e790c7.js"></script>
# <script>
# ysf.config({
# mobile:"", // 企业电话，暂无
# data:JSON.stringify(
# [
# {
# "index":0,
# "key":"siteName",
# "label":"企业站点名称",
# "value":"浙江恒逸集团有限公司",
# "href":"http://hengyi.study.163.com"
# }
# ]
# )
# });
# </script>
# <script src="http://se.stu.126.net/pub/s/com/web/t_common_macro-common_m5_067e1f0a808d95beb601fff1a4758db0.js"></script>
# <script src="http://se.stu.126.net/pub/s/com/web/core_2c97bae31c27dd890799232e7e872889.js"></script>
# <script src="http://se.stu.126.net/pub/s/com/web/pt_com_web_member_login_7bf0192a8a17e1a021b8b8b3dc4d2712.js"></script>
# </body>
# </html>
